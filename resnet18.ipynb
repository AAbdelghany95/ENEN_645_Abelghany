# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
import re
import time
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import psutil
from collections import Counter
from torch.utils.data import DataLoader, Dataset, WeightedRandomSampler
from torchvision import models, transforms
from PIL import Image
from transformers import DistilBertModel, DistilBertTokenizer

# Debug snippet: Test moving each pretrained model separately
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Testing on device: {device}")

try:
    from torchvision.models import mobilenet_v2, MobileNet_V2_Weights
    temp_img = mobilenet_v2(weights=MobileNet_V2_Weights.IMAGENET1K_V1).to(device)
    print("MobileNetV2 moved successfully")
except Exception as e:
    print("Error moving MobileNetV2:", e)

try:
    temp_text = DistilBertModel.from_pretrained("distilbert-base-uncased").to(device)
    print("DistilBertModel moved successfully")
except Exception as e:
    print("Error moving DistilBertModel:", e)

# ----------------------------
# Data paths
# ----------------------------
TRAIN_PATH = "garbage_data/CVPR_2024_dataset_Train"
VAL_PATH   = "garbage_data/CVPR_2024_dataset_Val"
TEST_PATH  = "garbage_data/CVPR_2024_dataset_Test"

# ----------------------------
# Utility: Check RAM usage
# ----------------------------
def check_ram_usage(step):
    ram = psutil.virtual_memory()
    print(f"[{step}] RAM Usage: {ram.percent}% ({ram.used / 1e9:.2f} GB / {ram.total / 1e9:.2f} GB)")

# ----------------------------
# Data Loading Function
# ----------------------------
def load_dataset(directory):
    """
    Loads dataset from a folder structure where each subfolder corresponds to a class.
    Text is extracted from the image file name (by removing extension and replacing underscores).
    """
    image_paths, labels, texts = [], [], []
    # Create a mapping from folder name to label (0-based)
    class_folders = sorted(os.listdir(directory))
    label_map = {folder: idx for idx, folder in enumerate(class_folders)}
    print(f"Loading dataset from {directory}...")
    
    for label_folder in class_folders:
        folder_path = os.path.join(directory, label_folder)
        if os.path.isdir(folder_path):
            for file in sorted(os.listdir(folder_path)):
                file_path = os.path.join(folder_path, file)
                if os.path.isfile(file_path):
                    # Extract text from file name
                    file_name, _ = os.path.splitext(file)
                    text = file_name.replace('_', ' ')
                    text = re.sub(r'\d+', '', text)  # Optionally remove digits
                    texts.append(text)
                    labels.append(label_map[label_folder])
                    image_paths.append(file_path)
    print(f"✅ Dataset from {directory} loaded!")
    return np.array(texts), np.array(labels), np.array(image_paths)

# ----------------------------
# Load datasets
# ----------------------------
print("🚀 Starting dataset loading...")
texts_train, labels_train, image_paths_train = load_dataset(TRAIN_PATH)
texts_val, labels_val, image_paths_val       = load_dataset(VAL_PATH)
texts_test, labels_test, image_paths_test      = load_dataset(TEST_PATH)
print("✅ All datasets loaded successfully!")

# ----------------------------
# (Optional) Adjust labels if necessary
# ----------------------------
if np.min(labels_train) >= 1:
    labels_train = labels_train - 1
    labels_val   = labels_val - 1
    labels_test  = labels_test - 1

print("Unique labels in train set:", sorted(set(labels_train)))
print("Unique labels in val set:", sorted(set(labels_val)))
print("Unique labels in test set:", sorted(set(labels_test)))

# ----------------------------
# Compute class weights (for imbalanced datasets)
# ----------------------------
label_counts = Counter(labels_train)
total_samples = sum(label_counts.values())
class_weights = {label: total_samples / count for label, count in label_counts.items()}
weights = [class_weights[label] for label in labels_train]
sampler = WeightedRandomSampler(weights, num_samples=len(weights), replacement=True)

# ----------------------------
# Initialize Tokenizer and Image Transforms
# ----------------------------
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
image_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# ----------------------------
# Custom Dataset
# ----------------------------
import os
from torch.utils.data import Dataset
from PIL import Image

class CustomDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len, image_paths):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.image_paths = image_paths
    
    def __len__(self):
        return len(self.texts)
    
    def __getitem__(self, idx):
        text = str(self.texts[idx])
        label = torch.tensor(self.labels[idx], dtype=torch.long)
        image_path = self.image_paths[idx]
        
        # Tokenize text
        encoding = self.tokenizer(
            text,
            padding="max_length",
            truncation=True,
            max_length=self.max_len,
            return_tensors="pt"
        )
        
        # Load and transform image
        image = Image.open(image_path).convert("RGB")
        image = image_transforms(image)
        
        # Add the file name (only the base name)
        file_name = os.path.basename(image_path)
        
        return {
            'image': image,
            'input_ids': encoding['input_ids'].squeeze(0),
            'attention_mask': encoding['attention_mask'].squeeze(0),
            'label': label,
            'file_name': file_name
        }


# ----------------------------
# Create DataLoaders
# ----------------------------
max_len = 24
batch_size = 32

train_dataset = CustomDataset(texts_train, labels_train, tokenizer, max_len, image_paths_train)
val_dataset   = CustomDataset(texts_val, labels_val, tokenizer, max_len, image_paths_val)
test_dataset  = CustomDataset(texts_test, labels_test, tokenizer, max_len, image_paths_test)

train_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=sampler, num_workers=18, pin_memory=True)
val_loader   = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=18, pin_memory=True)
test_loader  = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=18, pin_memory=True)
print("✅ DataLoaders created successfully!")

# ----------------------------
# Define Attention-Based Fusion Model
# ----------------------------
class AttentionFusionModel(nn.Module):
    def __init__(self, num_classes=4, fusion_dim=256, dropout_prob=0.3):
        super(AttentionFusionModel, self).__init__()
        
        # ----- Image Branch: ResNet18 -----
        from torchvision.models import resnet18, ResNet18_Weights
        self.image_model = resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
        # Freeze all layers (or adjust as needed)
        for param in self.image_model.parameters():
            param.requires_grad = False
        # Replace the final fully connected layer with an identity so that the output is the feature vector (512-dim)
        self.image_model.fc = nn.Identity()
        # Project image features to the fusion space
        self.image_fc = nn.Sequential(
            nn.Linear(512, fusion_dim),
            nn.ReLU(),
            nn.Dropout(dropout_prob)
        )
        
        # ----- Text Branch: DistilBERT -----
        self.text_model = DistilBertModel.from_pretrained("distilbert-base-uncased")
        for param in self.text_model.parameters():
            param.requires_grad = False
        # Project text features ([CLS] token, 768-dim) to the fusion space
        self.text_fc = nn.Sequential(
            nn.Linear(768, fusion_dim),
            nn.ReLU(),
            nn.Dropout(dropout_prob)
        )
        
        # ----- Attention Fusion -----
        # Compute scalar attention weights for each modality
        self.attn_image = nn.Linear(fusion_dim, 1)
        self.attn_text  = nn.Linear(fusion_dim, 1)
        
        # ----- Final Classification -----
        self.classifier = nn.Sequential(
            nn.Linear(fusion_dim, fusion_dim),
            nn.ReLU(),
            nn.Dropout(dropout_prob),
            nn.Linear(fusion_dim, num_classes)
        )
    
    def forward(self, image, input_ids, attention_mask):
        # Image branch: Extract features from ResNet18 (512-dim) and project to fusion space
        img_features = self.image_model(image)              # [B, 512]
        img_features = self.image_fc(img_features)            # [B, fusion_dim]
        
        # Text branch: Extract DistilBERT features ([CLS] token, 768-dim) and project to fusion space
        text_outputs = self.text_model(input_ids=input_ids, attention_mask=attention_mask)
        text_features = text_outputs.last_hidden_state[:, 0, :]  # [B, 768]
        text_features = self.text_fc(text_features)             # [B, fusion_dim]
        
        # Compute attention scores for each modality
        attn_img = self.attn_image(img_features)    # [B, 1]
        attn_txt = self.attn_text(text_features)      # [B, 1]
        attn_scores = torch.cat([attn_img, attn_txt], dim=1)  # [B, 2]
        attn_weights = torch.softmax(attn_scores, dim=1)      # [B, 2]
        
        # Fuse modalities using the learned attention weights
        fused_features = attn_weights[:, 0].unsqueeze(1) * img_features + \
                         attn_weights[:, 1].unsqueeze(1) * text_features
        
        # Final classification
        logits = self.classifier(fused_features)
        return logits

# ----------------------------
# Initialize Model, Loss, Optimizer, and Device
# ----------------------------
print(f"🔧 Using device: {device}")
try:
    model = AttentionFusionModel(num_classes=4).to(device)
except Exception as e:
    print("Error during model.to(device):", e)
    raise

criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-4)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2, verbose=True)

# ----------------------------
# Training and Validation Loop
# ----------------------------
num_epochs = 25
early_stop_patience = 5
best_val_loss = float('inf')
early_stop_counter = 0
train_losses, val_losses = [], []

print("🚀 Starting training...")
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0.0
    start_time = time.time()
    print(f"🔥 Epoch {epoch+1}/{num_epochs} started")
    
    for batch_idx, batch in enumerate(train_loader):
        optimizer.zero_grad()
        images = batch['image'].to(device)
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['label'].to(device)
        
        outputs = model(images, input_ids, attention_mask)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        if batch_idx % 10 == 0:
            print(f"🟢 Epoch {epoch+1}, Batch {batch_idx}, Loss: {loss.item():.4f}")
    
    train_loss = epoch_loss / len(train_loader)
    train_losses.append(train_loss)
    print(f"Train Loss: {train_loss:.4f}")
    
    # Validation step
    model.eval()
    val_loss = 0.0
    correct = 0
    with torch.no_grad():
        for batch in val_loader:
            images = batch['image'].to(device)
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['label'].to(device)
            
            outputs = model(images, input_ids, attention_mask)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            preds = torch.argmax(outputs, dim=1)
            correct += torch.sum(preds == labels).item()
    
    avg_val_loss = val_loss / len(val_loader)
    val_losses.append(avg_val_loss)
    val_acc = correct / len(val_dataset)
    epoch_time = time.time() - start_time
    print(f"🔵 Val Loss: {avg_val_loss:.4f}, Val Acc: {val_acc:.4f}, Epoch Time: {epoch_time:.2f} sec")
    scheduler.step(avg_val_loss)

    # Early stopping check
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        early_stop_counter = 0
        torch.save(model.state_dict(), "best_model.pth")
    else:
        early_stop_counter += 1
        if early_stop_counter >= early_stop_patience:
            print("⏹️ Early stopping triggered!")
            break

print("🎯 Training completed!")

# ----------------------------
# Testing
# ----------------------------
model.load_state_dict(torch.load("best_model.pth"))
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for batch in test_loader:
        images = batch['image'].to(device)
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['label'].to(device)
        
        outputs = model(images, input_ids, attention_mask)
        preds = torch.argmax(outputs, dim=1)
        correct += torch.sum(preds == labels).item()
        total += labels.size(0)

test_acc = correct / total
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# 2025-02-27 16:35:25.032741: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-27 16:35:25.090770: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740699325.113885   15605 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740699325.121473   15605 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-27 16:35:25.171928: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Testing on device: cuda
# MobileNetV2 moved successfully
# DistilBertModel moved successfully
# 🚀 Starting dataset loading...
# Loading dataset from garbage_data/CVPR_2024_dataset_Train...
# ✅ Dataset from garbage_data/CVPR_2024_dataset_Train loaded!
# Loading dataset from garbage_data/CVPR_2024_dataset_Val...
# ✅ Dataset from garbage_data/CVPR_2024_dataset_Val loaded!
# Loading dataset from garbage_data/CVPR_2024_dataset_Test...
# ✅ Dataset from garbage_data/CVPR_2024_dataset_Test loaded!
# ✅ All datasets loaded successfully!
# Unique labels in train set: [np.int64(0), np.int64(1), np.int64(2), np.int64(3)]
# Unique labels in val set: [np.int64(0), np.int64(1), np.int64(2), np.int64(3)]
# Unique labels in test set: [np.int64(0), np.int64(1), np.int64(2), np.int64(3)]
# ✅ DataLoaders created successfully!
# 🔧 Using device: cuda
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /home/abdghny95/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████████████████████████████████████████████████████████████████████████| 44.7M/44.7M [00:00<00:00, 77.4MB/s]
# 🚀 Starting training...
# 🔥 Epoch 1/25 started
# /home/abdghny95/miniconda3/envs/pytorch-env/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# 🟢 Epoch 1, Batch 0, Loss: 1.4027
# 🟢 Epoch 1, Batch 10, Loss: 1.3815
# 🟢 Epoch 1, Batch 20, Loss: 1.3772
# 🟢 Epoch 1, Batch 30, Loss: 1.3612
# 🟢 Epoch 1, Batch 40, Loss: 1.3477
# 🟢 Epoch 1, Batch 50, Loss: 1.3215
# 🟢 Epoch 1, Batch 60, Loss: 1.3037
# 🟢 Epoch 1, Batch 70, Loss: 1.3053
# 🟢 Epoch 1, Batch 80, Loss: 1.1946
# 🟢 Epoch 1, Batch 90, Loss: 1.2105
# 🟢 Epoch 1, Batch 100, Loss: 1.1437
# 🟢 Epoch 1, Batch 110, Loss: 1.0568
# 🟢 Epoch 1, Batch 120, Loss: 1.1774
# 🟢 Epoch 1, Batch 130, Loss: 0.9908
# 🟢 Epoch 1, Batch 140, Loss: 1.1140
# 🟢 Epoch 1, Batch 150, Loss: 1.0231
# 🟢 Epoch 1, Batch 160, Loss: 1.1440
# 🟢 Epoch 1, Batch 170, Loss: 0.9563
# 🟢 Epoch 1, Batch 180, Loss: 0.9088
# 🟢 Epoch 1, Batch 190, Loss: 0.8486
# 🟢 Epoch 1, Batch 200, Loss: 0.9332
# 🟢 Epoch 1, Batch 210, Loss: 0.6991
# 🟢 Epoch 1, Batch 220, Loss: 0.8531
# 🟢 Epoch 1, Batch 230, Loss: 0.8455
# 🟢 Epoch 1, Batch 240, Loss: 0.8456
# 🟢 Epoch 1, Batch 250, Loss: 0.8929
# 🟢 Epoch 1, Batch 260, Loss: 0.9576
# 🟢 Epoch 1, Batch 270, Loss: 1.0227
# 🟢 Epoch 1, Batch 280, Loss: 0.9143
# 🟢 Epoch 1, Batch 290, Loss: 0.8611
# 🟢 Epoch 1, Batch 300, Loss: 0.8066
# 🟢 Epoch 1, Batch 310, Loss: 0.8054
# 🟢 Epoch 1, Batch 320, Loss: 0.6971
# 🟢 Epoch 1, Batch 330, Loss: 0.7682
# 🟢 Epoch 1, Batch 340, Loss: 0.8573
# 🟢 Epoch 1, Batch 350, Loss: 0.9709
# 🟢 Epoch 1, Batch 360, Loss: 0.8958
# Train Loss: 1.0577
# 🔵 Val Loss: 0.8495, Val Acc: 0.6539, Epoch Time: 83.24 sec
# 🔥 Epoch 2/25 started
# 🟢 Epoch 2, Batch 0, Loss: 0.7871
# 🟢 Epoch 2, Batch 10, Loss: 0.7003
# 🟢 Epoch 2, Batch 20, Loss: 1.0681
# 🟢 Epoch 2, Batch 30, Loss: 0.9251
# 🟢 Epoch 2, Batch 40, Loss: 0.7232
# 🟢 Epoch 2, Batch 50, Loss: 0.9635
# 🟢 Epoch 2, Batch 60, Loss: 0.5940
# 🟢 Epoch 2, Batch 70, Loss: 0.9621
# 🟢 Epoch 2, Batch 80, Loss: 0.8675
# 🟢 Epoch 2, Batch 90, Loss: 0.6043
# 🟢 Epoch 2, Batch 100, Loss: 0.7560
# 🟢 Epoch 2, Batch 110, Loss: 0.8772
# 🟢 Epoch 2, Batch 120, Loss: 0.8818
# 🟢 Epoch 2, Batch 130, Loss: 0.6252
# 🟢 Epoch 2, Batch 140, Loss: 0.9298
# 🟢 Epoch 2, Batch 150, Loss: 0.6675
# 🟢 Epoch 2, Batch 160, Loss: 0.5918
# 🟢 Epoch 2, Batch 170, Loss: 0.7824
# 🟢 Epoch 2, Batch 180, Loss: 0.9159
# 🟢 Epoch 2, Batch 190, Loss: 0.7463
# 🟢 Epoch 2, Batch 200, Loss: 0.7321
# 🟢 Epoch 2, Batch 210, Loss: 0.8538
# 🟢 Epoch 2, Batch 220, Loss: 0.6872
# 🟢 Epoch 2, Batch 230, Loss: 0.6673
# 🟢 Epoch 2, Batch 240, Loss: 0.6592
# 🟢 Epoch 2, Batch 250, Loss: 0.6042
# 🟢 Epoch 2, Batch 260, Loss: 0.8085
# 🟢 Epoch 2, Batch 270, Loss: 0.5342
# 🟢 Epoch 2, Batch 280, Loss: 0.6023
# 🟢 Epoch 2, Batch 290, Loss: 0.7591
# 🟢 Epoch 2, Batch 300, Loss: 0.4452
# 🟢 Epoch 2, Batch 310, Loss: 0.5601
# 🟢 Epoch 2, Batch 320, Loss: 0.7721
# 🟢 Epoch 2, Batch 330, Loss: 0.6853
# 🟢 Epoch 2, Batch 340, Loss: 0.7258
# 🟢 Epoch 2, Batch 350, Loss: 0.6228
# 🟢 Epoch 2, Batch 360, Loss: 0.8729
# Train Loss: 0.7660
# 🔵 Val Loss: 0.6285, Val Acc: 0.7794, Epoch Time: 104.21 sec
# 🔥 Epoch 3/25 started
# 🟢 Epoch 3, Batch 0, Loss: 0.7057
# 🟢 Epoch 3, Batch 10, Loss: 0.9068
# 🟢 Epoch 3, Batch 20, Loss: 0.4966
# 🟢 Epoch 3, Batch 30, Loss: 0.6712
# 🟢 Epoch 3, Batch 40, Loss: 0.4896
# 🟢 Epoch 3, Batch 50, Loss: 0.7392
# 🟢 Epoch 3, Batch 60, Loss: 0.8786
# 🟢 Epoch 3, Batch 70, Loss: 0.8331
# 🟢 Epoch 3, Batch 80, Loss: 0.5371
# 🟢 Epoch 3, Batch 90, Loss: 0.5307
# 🟢 Epoch 3, Batch 100, Loss: 0.5142
# 🟢 Epoch 3, Batch 110, Loss: 0.7492
# 🟢 Epoch 3, Batch 120, Loss: 0.5501
# 🟢 Epoch 3, Batch 130, Loss: 0.5723
# 🟢 Epoch 3, Batch 140, Loss: 0.8574
# 🟢 Epoch 3, Batch 150, Loss: 0.6704
# 🟢 Epoch 3, Batch 160, Loss: 0.5635
# 🟢 Epoch 3, Batch 170, Loss: 0.6913
# 🟢 Epoch 3, Batch 180, Loss: 0.6243
# 🟢 Epoch 3, Batch 190, Loss: 0.4640
# 🟢 Epoch 3, Batch 200, Loss: 0.6051
# 🟢 Epoch 3, Batch 210, Loss: 0.5542
# 🟢 Epoch 3, Batch 220, Loss: 0.4639
# 🟢 Epoch 3, Batch 230, Loss: 0.8968
# 🟢 Epoch 3, Batch 240, Loss: 0.5974
# 🟢 Epoch 3, Batch 250, Loss: 0.5655
# 🟢 Epoch 3, Batch 260, Loss: 0.4706
# 🟢 Epoch 3, Batch 270, Loss: 0.5639
# 🟢 Epoch 3, Batch 280, Loss: 0.9326
# 🟢 Epoch 3, Batch 290, Loss: 0.5894
# 🟢 Epoch 3, Batch 300, Loss: 0.5998
# 🟢 Epoch 3, Batch 310, Loss: 0.5903
# 🟢 Epoch 3, Batch 320, Loss: 0.8862
# 🟢 Epoch 3, Batch 330, Loss: 0.5896
# 🟢 Epoch 3, Batch 340, Loss: 0.3841
# 🟢 Epoch 3, Batch 350, Loss: 0.3872
# 🟢 Epoch 3, Batch 360, Loss: 0.5602
# Train Loss: 0.6093
# 🔵 Val Loss: 0.5303, Val Acc: 0.8050, Epoch Time: 124.14 sec
# 🔥 Epoch 4/25 started
# 🟢 Epoch 4, Batch 0, Loss: 0.6226
# 🟢 Epoch 4, Batch 10, Loss: 0.3987
# 🟢 Epoch 4, Batch 20, Loss: 0.4724
# 🟢 Epoch 4, Batch 30, Loss: 0.7307
# 🟢 Epoch 4, Batch 40, Loss: 0.5834
# 🟢 Epoch 4, Batch 50, Loss: 0.4683
# 🟢 Epoch 4, Batch 60, Loss: 0.5645
# 🟢 Epoch 4, Batch 70, Loss: 0.4736
# 🟢 Epoch 4, Batch 80, Loss: 0.6598
# 🟢 Epoch 4, Batch 90, Loss: 0.8749
# 🟢 Epoch 4, Batch 100, Loss: 0.3820
# 🟢 Epoch 4, Batch 110, Loss: 0.5130
# 🟢 Epoch 4, Batch 120, Loss: 0.5784
# 🟢 Epoch 4, Batch 130, Loss: 0.8441
# 🟢 Epoch 4, Batch 140, Loss: 0.5913
# 🟢 Epoch 4, Batch 150, Loss: 0.4566
# 🟢 Epoch 4, Batch 160, Loss: 0.7357
# 🟢 Epoch 4, Batch 170, Loss: 0.5603
# 🟢 Epoch 4, Batch 180, Loss: 0.7073
# 🟢 Epoch 4, Batch 190, Loss: 0.6682
# 🟢 Epoch 4, Batch 200, Loss: 0.6369
# 🟢 Epoch 4, Batch 210, Loss: 0.5594
# 🟢 Epoch 4, Batch 220, Loss: 0.4065
# 🟢 Epoch 4, Batch 230, Loss: 0.5031
# 🟢 Epoch 4, Batch 240, Loss: 0.5917
# 🟢 Epoch 4, Batch 250, Loss: 0.5080
# 🟢 Epoch 4, Batch 260, Loss: 0.5616
# 🟢 Epoch 4, Batch 270, Loss: 0.6606
# 🟢 Epoch 4, Batch 280, Loss: 0.5715
# 🟢 Epoch 4, Batch 290, Loss: 0.2931
# 🟢 Epoch 4, Batch 300, Loss: 0.4020
# 🟢 Epoch 4, Batch 310, Loss: 0.5971
# 🟢 Epoch 4, Batch 320, Loss: 0.5212
# 🟢 Epoch 4, Batch 330, Loss: 0.5479
# 🟢 Epoch 4, Batch 340, Loss: 0.5766
# 🟢 Epoch 4, Batch 350, Loss: 0.6450
# 🟢 Epoch 4, Batch 360, Loss: 0.6951
# Train Loss: 0.5497
# 🔵 Val Loss: 0.4959, Val Acc: 0.8161, Epoch Time: 131.13 sec
# 🔥 Epoch 5/25 started
# 🟢 Epoch 5, Batch 0, Loss: 0.4895
# 🟢 Epoch 5, Batch 10, Loss: 0.7826
# 🟢 Epoch 5, Batch 20, Loss: 0.4587
# 🟢 Epoch 5, Batch 30, Loss: 0.4031
# 🟢 Epoch 5, Batch 40, Loss: 0.3588
# 🟢 Epoch 5, Batch 50, Loss: 0.3662
# 🟢 Epoch 5, Batch 60, Loss: 0.3979
# 🟢 Epoch 5, Batch 70, Loss: 0.5180
# 🟢 Epoch 5, Batch 80, Loss: 0.2742
# 🟢 Epoch 5, Batch 90, Loss: 0.3389
# 🟢 Epoch 5, Batch 100, Loss: 0.5689
# 🟢 Epoch 5, Batch 110, Loss: 0.3048
# 🟢 Epoch 5, Batch 120, Loss: 0.6257
# 🟢 Epoch 5, Batch 130, Loss: 0.4472
# 🟢 Epoch 5, Batch 140, Loss: 0.2771
# 🟢 Epoch 5, Batch 150, Loss: 0.3479
# 🟢 Epoch 5, Batch 160, Loss: 0.5220
# 🟢 Epoch 5, Batch 170, Loss: 0.4807
# 🟢 Epoch 5, Batch 180, Loss: 0.3793
# 🟢 Epoch 5, Batch 190, Loss: 0.7931
# 🟢 Epoch 5, Batch 200, Loss: 0.4021
# 🟢 Epoch 5, Batch 210, Loss: 0.6524
# 🟢 Epoch 5, Batch 220, Loss: 0.4571
# 🟢 Epoch 5, Batch 230, Loss: 0.6481
# 🟢 Epoch 5, Batch 240, Loss: 0.4778
# 🟢 Epoch 5, Batch 250, Loss: 0.7080
# 🟢 Epoch 5, Batch 260, Loss: 0.5395
# 🟢 Epoch 5, Batch 270, Loss: 0.3809
# 🟢 Epoch 5, Batch 280, Loss: 0.4127
# 🟢 Epoch 5, Batch 290, Loss: 0.4617
# 🟢 Epoch 5, Batch 300, Loss: 0.5664
# 🟢 Epoch 5, Batch 310, Loss: 0.4808
# 🟢 Epoch 5, Batch 320, Loss: 0.2632
# 🟢 Epoch 5, Batch 330, Loss: 0.5576
# 🟢 Epoch 5, Batch 340, Loss: 0.3704
# 🟢 Epoch 5, Batch 350, Loss: 0.3077
# 🟢 Epoch 5, Batch 360, Loss: 0.5461
# Train Loss: 0.4958
# 🔵 Val Loss: 0.4838, Val Acc: 0.8283, Epoch Time: 135.83 sec
# 🔥 Epoch 6/25 started
# 🟢 Epoch 6, Batch 0, Loss: 0.5917
# 🟢 Epoch 6, Batch 10, Loss: 0.3922
# 🟢 Epoch 6, Batch 20, Loss: 0.4948
# 🟢 Epoch 6, Batch 30, Loss: 0.3979
# 🟢 Epoch 6, Batch 40, Loss: 0.2915
# 🟢 Epoch 6, Batch 50, Loss: 0.4562
# 🟢 Epoch 6, Batch 60, Loss: 0.5501
# 🟢 Epoch 6, Batch 70, Loss: 0.4111
# 🟢 Epoch 6, Batch 80, Loss: 0.4726
# 🟢 Epoch 6, Batch 90, Loss: 0.3386
# 🟢 Epoch 6, Batch 100, Loss: 0.5218
# 🟢 Epoch 6, Batch 110, Loss: 0.4020
# 🟢 Epoch 6, Batch 120, Loss: 0.5992
# 🟢 Epoch 6, Batch 130, Loss: 0.4455
# 🟢 Epoch 6, Batch 140, Loss: 0.5278
# 🟢 Epoch 6, Batch 150, Loss: 0.5062
# 🟢 Epoch 6, Batch 160, Loss: 0.2763
# 🟢 Epoch 6, Batch 170, Loss: 0.4634
# 🟢 Epoch 6, Batch 180, Loss: 0.4123
# 🟢 Epoch 6, Batch 190, Loss: 0.2564
# 🟢 Epoch 6, Batch 200, Loss: 0.4738
# 🟢 Epoch 6, Batch 210, Loss: 0.3978
# 🟢 Epoch 6, Batch 220, Loss: 0.3011
# 🟢 Epoch 6, Batch 230, Loss: 0.4374
# 🟢 Epoch 6, Batch 240, Loss: 0.3148
# 🟢 Epoch 6, Batch 250, Loss: 0.3894
# 🟢 Epoch 6, Batch 260, Loss: 0.4343
# 🟢 Epoch 6, Batch 270, Loss: 0.5014
# 🟢 Epoch 6, Batch 280, Loss: 0.3776
# 🟢 Epoch 6, Batch 290, Loss: 0.5470
# 🟢 Epoch 6, Batch 300, Loss: 0.3077
# 🟢 Epoch 6, Batch 310, Loss: 0.4308
# 🟢 Epoch 6, Batch 320, Loss: 0.4362
# 🟢 Epoch 6, Batch 330, Loss: 0.6880
# 🟢 Epoch 6, Batch 340, Loss: 0.4660
# 🟢 Epoch 6, Batch 350, Loss: 0.3513
# 🟢 Epoch 6, Batch 360, Loss: 0.4464
# Train Loss: 0.4746
# 🔵 Val Loss: 0.4763, Val Acc: 0.8300, Epoch Time: 137.40 sec
# 🔥 Epoch 7/25 started
# 🟢 Epoch 7, Batch 0, Loss: 0.5826
# 🟢 Epoch 7, Batch 10, Loss: 0.4438
# 🟢 Epoch 7, Batch 20, Loss: 0.5554
# 🟢 Epoch 7, Batch 30, Loss: 0.2749
# 🟢 Epoch 7, Batch 40, Loss: 0.3988
# 🟢 Epoch 7, Batch 50, Loss: 0.5149
# 🟢 Epoch 7, Batch 60, Loss: 0.4695
# 🟢 Epoch 7, Batch 70, Loss: 0.6488
# 🟢 Epoch 7, Batch 80, Loss: 0.7118
# 🟢 Epoch 7, Batch 90, Loss: 0.4656
# 🟢 Epoch 7, Batch 100, Loss: 0.6381
# 🟢 Epoch 7, Batch 110, Loss: 0.2889
# 🟢 Epoch 7, Batch 120, Loss: 0.3890
# 🟢 Epoch 7, Batch 130, Loss: 0.4407
# 🟢 Epoch 7, Batch 140, Loss: 0.4694
# 🟢 Epoch 7, Batch 150, Loss: 0.2992
# 🟢 Epoch 7, Batch 160, Loss: 0.4728
# 🟢 Epoch 7, Batch 170, Loss: 0.2738
# 🟢 Epoch 7, Batch 180, Loss: 0.7835
# 🟢 Epoch 7, Batch 190, Loss: 0.5110
# 🟢 Epoch 7, Batch 200, Loss: 0.4759
# 🟢 Epoch 7, Batch 210, Loss: 0.2236
# 🟢 Epoch 7, Batch 220, Loss: 0.5037
# 🟢 Epoch 7, Batch 230, Loss: 0.5110
# 🟢 Epoch 7, Batch 240, Loss: 0.4837
# 🟢 Epoch 7, Batch 250, Loss: 0.2817
# 🟢 Epoch 7, Batch 260, Loss: 0.3923
# 🟢 Epoch 7, Batch 270, Loss: 0.6648
# 🟢 Epoch 7, Batch 280, Loss: 0.3387
# 🟢 Epoch 7, Batch 290, Loss: 0.3981
# 🟢 Epoch 7, Batch 300, Loss: 0.3201
# 🟢 Epoch 7, Batch 310, Loss: 0.2023
# 🟢 Epoch 7, Batch 320, Loss: 0.3238
# 🟢 Epoch 7, Batch 330, Loss: 0.7361
# 🟢 Epoch 7, Batch 340, Loss: 0.4071
# 🟢 Epoch 7, Batch 350, Loss: 0.5120
# 🟢 Epoch 7, Batch 360, Loss: 0.5458
# Train Loss: 0.4464
# 🔵 Val Loss: 0.4638, Val Acc: 0.8244, Epoch Time: 137.85 sec
# 🔥 Epoch 8/25 started
# 🟢 Epoch 8, Batch 0, Loss: 0.3956
# 🟢 Epoch 8, Batch 10, Loss: 0.4415
# 🟢 Epoch 8, Batch 20, Loss: 0.4554
# 🟢 Epoch 8, Batch 30, Loss: 0.4020
# 🟢 Epoch 8, Batch 40, Loss: 0.6087
# 🟢 Epoch 8, Batch 50, Loss: 0.2968
# 🟢 Epoch 8, Batch 60, Loss: 0.6390
# 🟢 Epoch 8, Batch 70, Loss: 0.3132
# 🟢 Epoch 8, Batch 80, Loss: 0.3507
# 🟢 Epoch 8, Batch 90, Loss: 0.4290
# 🟢 Epoch 8, Batch 100, Loss: 0.4057
# 🟢 Epoch 8, Batch 110, Loss: 0.5533
# 🟢 Epoch 8, Batch 120, Loss: 0.4562
# 🟢 Epoch 8, Batch 130, Loss: 0.4464
# 🟢 Epoch 8, Batch 140, Loss: 0.2455
# 🟢 Epoch 8, Batch 150, Loss: 0.3723
# 🟢 Epoch 8, Batch 160, Loss: 0.6103
# 🟢 Epoch 8, Batch 170, Loss: 0.4603
# 🟢 Epoch 8, Batch 180, Loss: 0.4936
# 🟢 Epoch 8, Batch 190, Loss: 0.4522
# 🟢 Epoch 8, Batch 200, Loss: 0.2507
# 🟢 Epoch 8, Batch 210, Loss: 0.2221
# 🟢 Epoch 8, Batch 220, Loss: 0.6320
# 🟢 Epoch 8, Batch 230, Loss: 0.4777
# 🟢 Epoch 8, Batch 240, Loss: 0.6390
# 🟢 Epoch 8, Batch 250, Loss: 0.2601
# 🟢 Epoch 8, Batch 260, Loss: 0.5228
# 🟢 Epoch 8, Batch 270, Loss: 0.3556
# 🟢 Epoch 8, Batch 280, Loss: 0.6211
# 🟢 Epoch 8, Batch 290, Loss: 0.5314
# 🟢 Epoch 8, Batch 300, Loss: 0.3705
# 🟢 Epoch 8, Batch 310, Loss: 0.4076
# 🟢 Epoch 8, Batch 320, Loss: 0.4488
# 🟢 Epoch 8, Batch 330, Loss: 0.4115
# 🟢 Epoch 8, Batch 340, Loss: 0.5276
# 🟢 Epoch 8, Batch 350, Loss: 0.4662
# 🟢 Epoch 8, Batch 360, Loss: 0.2083
# Train Loss: 0.4437
# 🔵 Val Loss: 0.4762, Val Acc: 0.8217, Epoch Time: 140.57 sec
# 🔥 Epoch 9/25 started
# 🟢 Epoch 9, Batch 0, Loss: 0.4430
# 🟢 Epoch 9, Batch 10, Loss: 0.3063
# 🟢 Epoch 9, Batch 20, Loss: 0.4259
# 🟢 Epoch 9, Batch 30, Loss: 0.5193
# 🟢 Epoch 9, Batch 40, Loss: 0.5419
# 🟢 Epoch 9, Batch 50, Loss: 0.5030
# 🟢 Epoch 9, Batch 60, Loss: 0.5254
# 🟢 Epoch 9, Batch 70, Loss: 0.5183
# 🟢 Epoch 9, Batch 80, Loss: 0.3608
# 🟢 Epoch 9, Batch 90, Loss: 0.3676
# 🟢 Epoch 9, Batch 100, Loss: 0.5318
# 🟢 Epoch 9, Batch 110, Loss: 0.4944
# 🟢 Epoch 9, Batch 120, Loss: 0.3407
# 🟢 Epoch 9, Batch 130, Loss: 0.4261
# 🟢 Epoch 9, Batch 140, Loss: 0.3581
# 🟢 Epoch 9, Batch 150, Loss: 0.5872
# 🟢 Epoch 9, Batch 160, Loss: 0.6239
# 🟢 Epoch 9, Batch 170, Loss: 0.2407
# 🟢 Epoch 9, Batch 180, Loss: 0.3959
# 🟢 Epoch 9, Batch 190, Loss: 0.4010
# 🟢 Epoch 9, Batch 200, Loss: 0.5183
# 🟢 Epoch 9, Batch 210, Loss: 0.3464
# 🟢 Epoch 9, Batch 220, Loss: 0.3090
# 🟢 Epoch 9, Batch 230, Loss: 0.4517
# 🟢 Epoch 9, Batch 240, Loss: 0.4298
# 🟢 Epoch 9, Batch 250, Loss: 0.4781
# 🟢 Epoch 9, Batch 260, Loss: 0.7637
# 🟢 Epoch 9, Batch 270, Loss: 0.4670
# 🟢 Epoch 9, Batch 280, Loss: 0.4127
# 🟢 Epoch 9, Batch 290, Loss: 0.6238
# 🟢 Epoch 9, Batch 300, Loss: 0.3238
# 🟢 Epoch 9, Batch 310, Loss: 0.3866
# 🟢 Epoch 9, Batch 320, Loss: 0.2885
# 🟢 Epoch 9, Batch 330, Loss: 0.2855
# 🟢 Epoch 9, Batch 340, Loss: 0.4135
# 🟢 Epoch 9, Batch 350, Loss: 0.5723
# 🟢 Epoch 9, Batch 360, Loss: 0.3573
# Train Loss: 0.4093
# 🔵 Val Loss: 0.4504, Val Acc: 0.8344, Epoch Time: 137.38 sec
# 🔥 Epoch 10/25 started
# 🟢 Epoch 10, Batch 0, Loss: 0.1400
# 🟢 Epoch 10, Batch 10, Loss: 0.1270
# 🟢 Epoch 10, Batch 20, Loss: 0.4080
# 🟢 Epoch 10, Batch 30, Loss: 0.3472
# 🟢 Epoch 10, Batch 40, Loss: 0.6014
# 🟢 Epoch 10, Batch 50, Loss: 0.3114
# 🟢 Epoch 10, Batch 60, Loss: 0.7258
# 🟢 Epoch 10, Batch 70, Loss: 0.3708
# 🟢 Epoch 10, Batch 80, Loss: 0.2309
# 🟢 Epoch 10, Batch 90, Loss: 0.4461
# 🟢 Epoch 10, Batch 100, Loss: 0.3560
# 🟢 Epoch 10, Batch 110, Loss: 0.1976
# 🟢 Epoch 10, Batch 120, Loss: 0.2966
# 🟢 Epoch 10, Batch 130, Loss: 0.2640
# 🟢 Epoch 10, Batch 140, Loss: 0.4499
# 🟢 Epoch 10, Batch 150, Loss: 0.6643
# 🟢 Epoch 10, Batch 160, Loss: 0.4501
# 🟢 Epoch 10, Batch 170, Loss: 0.5452
# 🟢 Epoch 10, Batch 180, Loss: 0.4917
# 🟢 Epoch 10, Batch 190, Loss: 0.3759
# 🟢 Epoch 10, Batch 200, Loss: 0.2998
# 🟢 Epoch 10, Batch 210, Loss: 0.3468
# 🟢 Epoch 10, Batch 220, Loss: 0.1890
# 🟢 Epoch 10, Batch 230, Loss: 0.4714
# 🟢 Epoch 10, Batch 240, Loss: 0.5344
# 🟢 Epoch 10, Batch 250, Loss: 0.3603
# 🟢 Epoch 10, Batch 260, Loss: 0.4371
# 🟢 Epoch 10, Batch 270, Loss: 0.4791
# 🟢 Epoch 10, Batch 280, Loss: 0.5122
# 🟢 Epoch 10, Batch 290, Loss: 0.5736
# 🟢 Epoch 10, Batch 300, Loss: 0.2972
# 🟢 Epoch 10, Batch 310, Loss: 0.1420
# 🟢 Epoch 10, Batch 320, Loss: 0.6019
# 🟢 Epoch 10, Batch 330, Loss: 0.3144
# 🟢 Epoch 10, Batch 340, Loss: 0.4486
# 🟢 Epoch 10, Batch 350, Loss: 0.1650
# 🟢 Epoch 10, Batch 360, Loss: 0.2520
# Train Loss: 0.3985
# 🔵 Val Loss: 0.4327, Val Acc: 0.8489, Epoch Time: 131.72 sec
# 🔥 Epoch 11/25 started
# 🟢 Epoch 11, Batch 0, Loss: 0.3378
# 🟢 Epoch 11, Batch 10, Loss: 0.4909
# 🟢 Epoch 11, Batch 20, Loss: 0.3426
# 🟢 Epoch 11, Batch 30, Loss: 0.6152
# 🟢 Epoch 11, Batch 40, Loss: 0.4669
# 🟢 Epoch 11, Batch 50, Loss: 0.2711
# 🟢 Epoch 11, Batch 60, Loss: 0.2342
# 🟢 Epoch 11, Batch 70, Loss: 0.2884
# 🟢 Epoch 11, Batch 80, Loss: 0.4984
# 🟢 Epoch 11, Batch 90, Loss: 0.5538
# 🟢 Epoch 11, Batch 100, Loss: 0.6528
# 🟢 Epoch 11, Batch 110, Loss: 0.3734
# 🟢 Epoch 11, Batch 120, Loss: 0.5553
# 🟢 Epoch 11, Batch 130, Loss: 0.1239
# 🟢 Epoch 11, Batch 140, Loss: 0.3426
# 🟢 Epoch 11, Batch 150, Loss: 0.4363
# 🟢 Epoch 11, Batch 160, Loss: 0.5737
# 🟢 Epoch 11, Batch 170, Loss: 0.3192
# 🟢 Epoch 11, Batch 180, Loss: 0.4499
# 🟢 Epoch 11, Batch 190, Loss: 0.4319
# 🟢 Epoch 11, Batch 200, Loss: 0.3571
# 🟢 Epoch 11, Batch 210, Loss: 0.4447
# 🟢 Epoch 11, Batch 220, Loss: 0.5336
# 🟢 Epoch 11, Batch 230, Loss: 0.6879
# 🟢 Epoch 11, Batch 240, Loss: 0.4627
# 🟢 Epoch 11, Batch 250, Loss: 0.2796
# 🟢 Epoch 11, Batch 260, Loss: 0.5419
# 🟢 Epoch 11, Batch 270, Loss: 0.4449
# 🟢 Epoch 11, Batch 280, Loss: 0.5504
# 🟢 Epoch 11, Batch 290, Loss: 0.3229
# 🟢 Epoch 11, Batch 300, Loss: 0.4544
# 🟢 Epoch 11, Batch 310, Loss: 0.2850
# 🟢 Epoch 11, Batch 320, Loss: 0.2289
# 🟢 Epoch 11, Batch 330, Loss: 0.4736
# 🟢 Epoch 11, Batch 340, Loss: 0.4492
# 🟢 Epoch 11, Batch 350, Loss: 0.3323
# 🟢 Epoch 11, Batch 360, Loss: 0.6623
# Train Loss: 0.3982
# 🔵 Val Loss: 0.4321, Val Acc: 0.8400, Epoch Time: 137.13 sec
# 🔥 Epoch 12/25 started
# 🟢 Epoch 12, Batch 0, Loss: 0.4308
# 🟢 Epoch 12, Batch 10, Loss: 0.5323
# 🟢 Epoch 12, Batch 20, Loss: 0.4027
# 🟢 Epoch 12, Batch 30, Loss: 0.4035
# 🟢 Epoch 12, Batch 40, Loss: 0.4015
# 🟢 Epoch 12, Batch 50, Loss: 0.2919
# 🟢 Epoch 12, Batch 60, Loss: 0.4409
# 🟢 Epoch 12, Batch 70, Loss: 0.3157
# 🟢 Epoch 12, Batch 80, Loss: 0.3621
# 🟢 Epoch 12, Batch 90, Loss: 0.5147
# 🟢 Epoch 12, Batch 100, Loss: 0.4633
# 🟢 Epoch 12, Batch 110, Loss: 0.4980
# 🟢 Epoch 12, Batch 120, Loss: 0.6886
# 🟢 Epoch 12, Batch 130, Loss: 0.2181
# 🟢 Epoch 12, Batch 140, Loss: 0.3969
# 🟢 Epoch 12, Batch 150, Loss: 0.4290
# 🟢 Epoch 12, Batch 160, Loss: 0.3285
# 🟢 Epoch 12, Batch 170, Loss: 0.6840
# 🟢 Epoch 12, Batch 180, Loss: 0.2729
# 🟢 Epoch 12, Batch 190, Loss: 0.4097
# 🟢 Epoch 12, Batch 200, Loss: 0.3592
# 🟢 Epoch 12, Batch 210, Loss: 0.2468
# 🟢 Epoch 12, Batch 220, Loss: 0.4145
# 🟢 Epoch 12, Batch 230, Loss: 0.4934
# 🟢 Epoch 12, Batch 240, Loss: 0.3832
# 🟢 Epoch 12, Batch 250, Loss: 0.2167
# 🟢 Epoch 12, Batch 260, Loss: 0.4088
# 🟢 Epoch 12, Batch 270, Loss: 0.3284
# 🟢 Epoch 12, Batch 280, Loss: 0.4519
# 🟢 Epoch 12, Batch 290, Loss: 0.3756
# 🟢 Epoch 12, Batch 300, Loss: 0.1961
# 🟢 Epoch 12, Batch 310, Loss: 0.2583
# 🟢 Epoch 12, Batch 320, Loss: 0.3604
# 🟢 Epoch 12, Batch 330, Loss: 0.3423
# 🟢 Epoch 12, Batch 340, Loss: 0.5053
# 🟢 Epoch 12, Batch 350, Loss: 0.2581
# 🟢 Epoch 12, Batch 360, Loss: 0.2914
# Train Loss: 0.3888
# 🔵 Val Loss: 0.4284, Val Acc: 0.8467, Epoch Time: 129.02 sec
# 🔥 Epoch 13/25 started
# 🟢 Epoch 13, Batch 0, Loss: 0.2023
# 🟢 Epoch 13, Batch 10, Loss: 0.4456
# 🟢 Epoch 13, Batch 20, Loss: 0.6314
# 🟢 Epoch 13, Batch 30, Loss: 0.2918
# 🟢 Epoch 13, Batch 40, Loss: 0.9368
# 🟢 Epoch 13, Batch 50, Loss: 0.4478
# 🟢 Epoch 13, Batch 60, Loss: 0.3100
# 🟢 Epoch 13, Batch 70, Loss: 0.3834
# 🟢 Epoch 13, Batch 80, Loss: 0.5211
# 🟢 Epoch 13, Batch 90, Loss: 0.4175
# 🟢 Epoch 13, Batch 100, Loss: 0.4014
# 🟢 Epoch 13, Batch 110, Loss: 0.5771
# 🟢 Epoch 13, Batch 120, Loss: 0.3623
# 🟢 Epoch 13, Batch 130, Loss: 0.4010
# 🟢 Epoch 13, Batch 140, Loss: 0.3479
# 🟢 Epoch 13, Batch 150, Loss: 0.4919
# 🟢 Epoch 13, Batch 160, Loss: 0.2920
# 🟢 Epoch 13, Batch 170, Loss: 0.1943
# 🟢 Epoch 13, Batch 180, Loss: 0.2325
# 🟢 Epoch 13, Batch 190, Loss: 0.2527
# 🟢 Epoch 13, Batch 200, Loss: 0.5094
# 🟢 Epoch 13, Batch 210, Loss: 0.6166
# 🟢 Epoch 13, Batch 220, Loss: 0.3536
# 🟢 Epoch 13, Batch 230, Loss: 0.3986
# 🟢 Epoch 13, Batch 240, Loss: 0.4805
# 🟢 Epoch 13, Batch 250, Loss: 0.4148
# 🟢 Epoch 13, Batch 260, Loss: 0.2890
# 🟢 Epoch 13, Batch 270, Loss: 0.3902
# 🟢 Epoch 13, Batch 280, Loss: 0.1577
# 🟢 Epoch 13, Batch 290, Loss: 0.1825
# 🟢 Epoch 13, Batch 300, Loss: 0.2685
# 🟢 Epoch 13, Batch 310, Loss: 0.4147
# 🟢 Epoch 13, Batch 320, Loss: 0.2198
# 🟢 Epoch 13, Batch 330, Loss: 0.4428
# 🟢 Epoch 13, Batch 340, Loss: 0.2795
# 🟢 Epoch 13, Batch 350, Loss: 0.3777
# 🟢 Epoch 13, Batch 360, Loss: 0.3345
# Train Loss: 0.3661
# 🔵 Val Loss: 0.4043, Val Acc: 0.8567, Epoch Time: 135.67 sec
# 🔥 Epoch 14/25 started
# 🟢 Epoch 14, Batch 0, Loss: 0.4387
# 🟢 Epoch 14, Batch 10, Loss: 0.2906
# 🟢 Epoch 14, Batch 20, Loss: 0.4141
# 🟢 Epoch 14, Batch 30, Loss: 0.3980
# 🟢 Epoch 14, Batch 40, Loss: 0.4709
# 🟢 Epoch 14, Batch 50, Loss: 0.3908
# 🟢 Epoch 14, Batch 60, Loss: 0.2305
# 🟢 Epoch 14, Batch 70, Loss: 0.2390
# 🟢 Epoch 14, Batch 80, Loss: 0.2911
# 🟢 Epoch 14, Batch 90, Loss: 0.2430
# 🟢 Epoch 14, Batch 100, Loss: 0.4662
# 🟢 Epoch 14, Batch 110, Loss: 0.4425
# 🟢 Epoch 14, Batch 120, Loss: 0.2122
# 🟢 Epoch 14, Batch 130, Loss: 0.3738
# 🟢 Epoch 14, Batch 140, Loss: 0.4010
# 🟢 Epoch 14, Batch 150, Loss: 0.3362
# 🟢 Epoch 14, Batch 160, Loss: 0.5136
# 🟢 Epoch 14, Batch 170, Loss: 0.3232
# 🟢 Epoch 14, Batch 180, Loss: 0.1783
# 🟢 Epoch 14, Batch 190, Loss: 0.3374
# 🟢 Epoch 14, Batch 200, Loss: 0.3215
# 🟢 Epoch 14, Batch 210, Loss: 0.3480
# 🟢 Epoch 14, Batch 220, Loss: 0.3329
# 🟢 Epoch 14, Batch 230, Loss: 0.3879
# 🟢 Epoch 14, Batch 240, Loss: 0.3699
# 🟢 Epoch 14, Batch 250, Loss: 0.4136
# 🟢 Epoch 14, Batch 260, Loss: 0.3746
# 🟢 Epoch 14, Batch 270, Loss: 0.4323
# 🟢 Epoch 14, Batch 280, Loss: 0.5019
# 🟢 Epoch 14, Batch 290, Loss: 0.2748
# 🟢 Epoch 14, Batch 300, Loss: 0.2336
# 🟢 Epoch 14, Batch 310, Loss: 0.2690
# 🟢 Epoch 14, Batch 320, Loss: 0.3187
# 🟢 Epoch 14, Batch 330, Loss: 0.3131
# 🟢 Epoch 14, Batch 340, Loss: 0.6251
# 🟢 Epoch 14, Batch 350, Loss: 0.2921
# 🟢 Epoch 14, Batch 360, Loss: 0.2016
# Train Loss: 0.3720
# 🔵 Val Loss: 0.4057, Val Acc: 0.8544, Epoch Time: 135.61 sec
# 🔥 Epoch 15/25 started
# 🟢 Epoch 15, Batch 0, Loss: 0.6890
# 🟢 Epoch 15, Batch 10, Loss: 0.2789
# 🟢 Epoch 15, Batch 20, Loss: 0.4414
# 🟢 Epoch 15, Batch 30, Loss: 0.1589
# 🟢 Epoch 15, Batch 40, Loss: 0.4878
# 🟢 Epoch 15, Batch 50, Loss: 0.6210
# 🟢 Epoch 15, Batch 60, Loss: 0.3827
# 🟢 Epoch 15, Batch 70, Loss: 0.4047
# 🟢 Epoch 15, Batch 80, Loss: 0.3688
# 🟢 Epoch 15, Batch 90, Loss: 0.1695
# 🟢 Epoch 15, Batch 100, Loss: 0.6227
# 🟢 Epoch 15, Batch 110, Loss: 0.1793
# 🟢 Epoch 15, Batch 120, Loss: 0.5428
# 🟢 Epoch 15, Batch 130, Loss: 0.5495
# 🟢 Epoch 15, Batch 140, Loss: 0.2910
# 🟢 Epoch 15, Batch 150, Loss: 0.5750
# 🟢 Epoch 15, Batch 160, Loss: 0.3081
# 🟢 Epoch 15, Batch 170, Loss: 0.2602
# 🟢 Epoch 15, Batch 180, Loss: 0.3174
# 🟢 Epoch 15, Batch 190, Loss: 0.2946
# 🟢 Epoch 15, Batch 200, Loss: 0.3439
# 🟢 Epoch 15, Batch 210, Loss: 0.3232
# 🟢 Epoch 15, Batch 220, Loss: 0.2261
# 🟢 Epoch 15, Batch 230, Loss: 0.2232
# 🟢 Epoch 15, Batch 240, Loss: 0.4128
# 🟢 Epoch 15, Batch 250, Loss: 0.5421
# 🟢 Epoch 15, Batch 260, Loss: 0.2826
# 🟢 Epoch 15, Batch 270, Loss: 0.3842
# 🟢 Epoch 15, Batch 280, Loss: 0.6305
# 🟢 Epoch 15, Batch 290, Loss: 0.4452
# 🟢 Epoch 15, Batch 300, Loss: 0.2633
# 🟢 Epoch 15, Batch 310, Loss: 0.1652
# 🟢 Epoch 15, Batch 320, Loss: 0.5598
# 🟢 Epoch 15, Batch 330, Loss: 0.2959
# 🟢 Epoch 15, Batch 340, Loss: 0.3040
# 🟢 Epoch 15, Batch 350, Loss: 0.1623
# 🟢 Epoch 15, Batch 360, Loss: 0.1737
# Train Loss: 0.3475
# 🔵 Val Loss: 0.4136, Val Acc: 0.8544, Epoch Time: 137.60 sec
# 🔥 Epoch 16/25 started
# 🟢 Epoch 16, Batch 0, Loss: 0.2974
# 🟢 Epoch 16, Batch 10, Loss: 0.1597
# 🟢 Epoch 16, Batch 20, Loss: 0.2265
# 🟢 Epoch 16, Batch 30, Loss: 0.2897
# 🟢 Epoch 16, Batch 40, Loss: 0.6111
# 🟢 Epoch 16, Batch 50, Loss: 0.2583
# 🟢 Epoch 16, Batch 60, Loss: 0.3722
# 🟢 Epoch 16, Batch 70, Loss: 0.4605
# 🟢 Epoch 16, Batch 80, Loss: 0.2106
# 🟢 Epoch 16, Batch 90, Loss: 0.2541
# 🟢 Epoch 16, Batch 100, Loss: 0.2993
# 🟢 Epoch 16, Batch 110, Loss: 0.4724
# 🟢 Epoch 16, Batch 120, Loss: 0.3920
# 🟢 Epoch 16, Batch 130, Loss: 0.4682
# 🟢 Epoch 16, Batch 140, Loss: 0.5638
# 🟢 Epoch 16, Batch 150, Loss: 0.4037
# 🟢 Epoch 16, Batch 160, Loss: 0.3355
# 🟢 Epoch 16, Batch 170, Loss: 0.1837
# 🟢 Epoch 16, Batch 180, Loss: 0.2054
# 🟢 Epoch 16, Batch 190, Loss: 0.2166
# 🟢 Epoch 16, Batch 200, Loss: 0.3120
# 🟢 Epoch 16, Batch 210, Loss: 0.2683
# 🟢 Epoch 16, Batch 220, Loss: 0.3076
# 🟢 Epoch 16, Batch 230, Loss: 0.3794
# 🟢 Epoch 16, Batch 240, Loss: 0.2725
# 🟢 Epoch 16, Batch 250, Loss: 0.3948
# 🟢 Epoch 16, Batch 260, Loss: 0.3875
# 🟢 Epoch 16, Batch 270, Loss: 0.3473
# 🟢 Epoch 16, Batch 280, Loss: 0.2732
# 🟢 Epoch 16, Batch 290, Loss: 0.3825
# 🟢 Epoch 16, Batch 300, Loss: 0.3261
# 🟢 Epoch 16, Batch 310, Loss: 0.2698
# 🟢 Epoch 16, Batch 320, Loss: 0.2585
# 🟢 Epoch 16, Batch 330, Loss: 0.2070
# 🟢 Epoch 16, Batch 340, Loss: 0.5531
# 🟢 Epoch 16, Batch 350, Loss: 0.3860
# 🟢 Epoch 16, Batch 360, Loss: 0.2283
# Train Loss: 0.3416
# 🔵 Val Loss: 0.3962, Val Acc: 0.8589, Epoch Time: 136.30 sec
# 🔥 Epoch 17/25 started
# 🟢 Epoch 17, Batch 0, Loss: 0.2837
# 🟢 Epoch 17, Batch 10, Loss: 0.2957
# 🟢 Epoch 17, Batch 20, Loss: 0.2838
# 🟢 Epoch 17, Batch 30, Loss: 0.3803
# 🟢 Epoch 17, Batch 40, Loss: 0.4205
# 🟢 Epoch 17, Batch 50, Loss: 0.3150
# 🟢 Epoch 17, Batch 60, Loss: 0.3555
# 🟢 Epoch 17, Batch 70, Loss: 0.3549
# 🟢 Epoch 17, Batch 80, Loss: 0.2379
# 🟢 Epoch 17, Batch 90, Loss: 0.5412
# 🟢 Epoch 17, Batch 100, Loss: 0.4124
# 🟢 Epoch 17, Batch 110, Loss: 0.2860
# 🟢 Epoch 17, Batch 120, Loss: 0.4584
# 🟢 Epoch 17, Batch 130, Loss: 0.3470
# 🟢 Epoch 17, Batch 140, Loss: 0.3945
# 🟢 Epoch 17, Batch 150, Loss: 0.3415
# 🟢 Epoch 17, Batch 160, Loss: 0.4769
# 🟢 Epoch 17, Batch 170, Loss: 0.3997
# 🟢 Epoch 17, Batch 180, Loss: 0.3392
# 🟢 Epoch 17, Batch 190, Loss: 0.2816
# 🟢 Epoch 17, Batch 200, Loss: 0.3476
# 🟢 Epoch 17, Batch 210, Loss: 0.1087
# 🟢 Epoch 17, Batch 220, Loss: 0.4161
# 🟢 Epoch 17, Batch 230, Loss: 0.2523
# 🟢 Epoch 17, Batch 240, Loss: 0.6480
# 🟢 Epoch 17, Batch 250, Loss: 0.3155
# 🟢 Epoch 17, Batch 260, Loss: 0.2207
# 🟢 Epoch 17, Batch 270, Loss: 0.2616
# 🟢 Epoch 17, Batch 280, Loss: 0.2917
# 🟢 Epoch 17, Batch 290, Loss: 0.6780
# 🟢 Epoch 17, Batch 300, Loss: 0.3019
# 🟢 Epoch 17, Batch 310, Loss: 0.3717
# 🟢 Epoch 17, Batch 320, Loss: 0.2082
# 🟢 Epoch 17, Batch 330, Loss: 0.4507
# 🟢 Epoch 17, Batch 340, Loss: 0.2343
# 🟢 Epoch 17, Batch 350, Loss: 0.3352
# 🟢 Epoch 17, Batch 360, Loss: 0.3111
# Train Loss: 0.3307
# 🔵 Val Loss: 0.4155, Val Acc: 0.8522, Epoch Time: 134.68 sec
# 🔥 Epoch 18/25 started
# 🟢 Epoch 18, Batch 0, Loss: 0.2967
# 🟢 Epoch 18, Batch 10, Loss: 0.1755
# 🟢 Epoch 18, Batch 20, Loss: 0.3075
# 🟢 Epoch 18, Batch 30, Loss: 0.1822
# 🟢 Epoch 18, Batch 40, Loss: 0.2759
# 🟢 Epoch 18, Batch 50, Loss: 0.1817
# 🟢 Epoch 18, Batch 60, Loss: 0.3661
# 🟢 Epoch 18, Batch 70, Loss: 0.1952
# 🟢 Epoch 18, Batch 80, Loss: 0.3415
# 🟢 Epoch 18, Batch 90, Loss: 0.2002
# 🟢 Epoch 18, Batch 100, Loss: 0.2519
# 🟢 Epoch 18, Batch 110, Loss: 0.7169
# 🟢 Epoch 18, Batch 120, Loss: 0.3735
# 🟢 Epoch 18, Batch 130, Loss: 0.3567
# 🟢 Epoch 18, Batch 140, Loss: 0.4381
# 🟢 Epoch 18, Batch 150, Loss: 0.3794
# 🟢 Epoch 18, Batch 160, Loss: 0.2888
# 🟢 Epoch 18, Batch 170, Loss: 0.1981
# 🟢 Epoch 18, Batch 180, Loss: 0.2441
# 🟢 Epoch 18, Batch 190, Loss: 0.2073
# 🟢 Epoch 18, Batch 200, Loss: 0.2370
# 🟢 Epoch 18, Batch 210, Loss: 0.2781
# 🟢 Epoch 18, Batch 220, Loss: 0.8319
# 🟢 Epoch 18, Batch 230, Loss: 0.2568
# 🟢 Epoch 18, Batch 240, Loss: 0.3067
# 🟢 Epoch 18, Batch 250, Loss: 0.1966
# 🟢 Epoch 18, Batch 260, Loss: 0.2702
# 🟢 Epoch 18, Batch 270, Loss: 0.3382
# 🟢 Epoch 18, Batch 280, Loss: 0.2816
# 🟢 Epoch 18, Batch 290, Loss: 0.4069
# 🟢 Epoch 18, Batch 300, Loss: 0.2743
# 🟢 Epoch 18, Batch 310, Loss: 0.2648
# 🟢 Epoch 18, Batch 320, Loss: 0.1448
# 🟢 Epoch 18, Batch 330, Loss: 0.3577
# 🟢 Epoch 18, Batch 340, Loss: 0.3464
# 🟢 Epoch 18, Batch 350, Loss: 0.3221
# 🟢 Epoch 18, Batch 360, Loss: 0.5151
# Train Loss: 0.3209
# 🔵 Val Loss: 0.4335, Val Acc: 0.8439, Epoch Time: 136.39 sec
# 🔥 Epoch 19/25 started
# 🟢 Epoch 19, Batch 0, Loss: 0.1945
# 🟢 Epoch 19, Batch 10, Loss: 0.2943
# 🟢 Epoch 19, Batch 20, Loss: 0.1417
# 🟢 Epoch 19, Batch 30, Loss: 0.2658
# 🟢 Epoch 19, Batch 40, Loss: 0.3377
# 🟢 Epoch 19, Batch 50, Loss: 0.2619
# 🟢 Epoch 19, Batch 60, Loss: 0.3763
# 🟢 Epoch 19, Batch 70, Loss: 0.2065
# 🟢 Epoch 19, Batch 80, Loss: 0.4446
# 🟢 Epoch 19, Batch 90, Loss: 0.4943
# 🟢 Epoch 19, Batch 100, Loss: 0.1814
# 🟢 Epoch 19, Batch 110, Loss: 0.6026
# 🟢 Epoch 19, Batch 120, Loss: 0.3668
# 🟢 Epoch 19, Batch 130, Loss: 0.3225
# 🟢 Epoch 19, Batch 140, Loss: 0.4650
# 🟢 Epoch 19, Batch 150, Loss: 0.2249
# 🟢 Epoch 19, Batch 160, Loss: 0.2886
# 🟢 Epoch 19, Batch 170, Loss: 0.1163
# 🟢 Epoch 19, Batch 180, Loss: 0.2211
# 🟢 Epoch 19, Batch 190, Loss: 0.2727
# 🟢 Epoch 19, Batch 200, Loss: 0.3289
# 🟢 Epoch 19, Batch 210, Loss: 0.5598
# 🟢 Epoch 19, Batch 220, Loss: 0.2950
# 🟢 Epoch 19, Batch 230, Loss: 0.2572
# 🟢 Epoch 19, Batch 240, Loss: 0.2164
# 🟢 Epoch 19, Batch 250, Loss: 0.8472
# 🟢 Epoch 19, Batch 260, Loss: 0.4059
# 🟢 Epoch 19, Batch 270, Loss: 0.4225
# 🟢 Epoch 19, Batch 280, Loss: 0.3735
# 🟢 Epoch 19, Batch 290, Loss: 0.2044
# 🟢 Epoch 19, Batch 300, Loss: 0.3202
# 🟢 Epoch 19, Batch 310, Loss: 0.4103
# 🟢 Epoch 19, Batch 320, Loss: 0.2586
# 🟢 Epoch 19, Batch 330, Loss: 0.2596
# 🟢 Epoch 19, Batch 340, Loss: 0.1714
# 🟢 Epoch 19, Batch 350, Loss: 0.2795
# 🟢 Epoch 19, Batch 360, Loss: 0.2355
# Train Loss: 0.3122
# 🔵 Val Loss: 0.4236, Val Acc: 0.8433, Epoch Time: 135.43 sec
# 🔥 Epoch 20/25 started
# 🟢 Epoch 20, Batch 0, Loss: 0.2176
# 🟢 Epoch 20, Batch 10, Loss: 0.2510
# 🟢 Epoch 20, Batch 20, Loss: 0.2422
# 🟢 Epoch 20, Batch 30, Loss: 0.4529
# 🟢 Epoch 20, Batch 40, Loss: 0.2801
# 🟢 Epoch 20, Batch 50, Loss: 0.3239
# 🟢 Epoch 20, Batch 60, Loss: 0.3558
# 🟢 Epoch 20, Batch 70, Loss: 0.0943
# 🟢 Epoch 20, Batch 80, Loss: 0.2379
# 🟢 Epoch 20, Batch 90, Loss: 0.3773
# 🟢 Epoch 20, Batch 100, Loss: 0.2640
# 🟢 Epoch 20, Batch 110, Loss: 0.3246
# 🟢 Epoch 20, Batch 120, Loss: 0.2325
# 🟢 Epoch 20, Batch 130, Loss: 0.2464
# 🟢 Epoch 20, Batch 140, Loss: 0.2627
# 🟢 Epoch 20, Batch 150, Loss: 0.1956
# 🟢 Epoch 20, Batch 160, Loss: 0.1739
# 🟢 Epoch 20, Batch 170, Loss: 0.5032
# 🟢 Epoch 20, Batch 180, Loss: 0.2544
# 🟢 Epoch 20, Batch 190, Loss: 0.3690
# 🟢 Epoch 20, Batch 200, Loss: 0.2257
# 🟢 Epoch 20, Batch 210, Loss: 0.2826
# 🟢 Epoch 20, Batch 220, Loss: 0.2792
# 🟢 Epoch 20, Batch 230, Loss: 0.2673
# 🟢 Epoch 20, Batch 240, Loss: 0.2443
# 🟢 Epoch 20, Batch 250, Loss: 0.1774
# 🟢 Epoch 20, Batch 260, Loss: 0.1802
# 🟢 Epoch 20, Batch 270, Loss: 0.1989
# 🟢 Epoch 20, Batch 280, Loss: 0.3301
# 🟢 Epoch 20, Batch 290, Loss: 0.1487
# 🟢 Epoch 20, Batch 300, Loss: 0.3253
# 🟢 Epoch 20, Batch 310, Loss: 0.4191
# 🟢 Epoch 20, Batch 320, Loss: 0.1799
# 🟢 Epoch 20, Batch 330, Loss: 0.3575
# 🟢 Epoch 20, Batch 340, Loss: 0.2974
# 🟢 Epoch 20, Batch 350, Loss: 0.5106
# 🟢 Epoch 20, Batch 360, Loss: 0.2655
# Train Loss: 0.3001
# 🔵 Val Loss: 0.4024, Val Acc: 0.8572, Epoch Time: 135.34 sec
# 🔥 Epoch 21/25 started
# 🟢 Epoch 21, Batch 0, Loss: 0.4856
# 🟢 Epoch 21, Batch 10, Loss: 0.4125
# 🟢 Epoch 21, Batch 20, Loss: 0.4392
# 🟢 Epoch 21, Batch 30, Loss: 0.3322
# 🟢 Epoch 21, Batch 40, Loss: 0.3197
# 🟢 Epoch 21, Batch 50, Loss: 0.3800
# 🟢 Epoch 21, Batch 60, Loss: 0.3235
# 🟢 Epoch 21, Batch 70, Loss: 0.2762
# 🟢 Epoch 21, Batch 80, Loss: 0.3915
# 🟢 Epoch 21, Batch 90, Loss: 0.1964
# 🟢 Epoch 21, Batch 100, Loss: 0.2084
# 🟢 Epoch 21, Batch 110, Loss: 0.1758
# 🟢 Epoch 21, Batch 120, Loss: 0.2049
# 🟢 Epoch 21, Batch 130, Loss: 0.2042
# 🟢 Epoch 21, Batch 140, Loss: 0.2571
# 🟢 Epoch 21, Batch 150, Loss: 0.2332
# 🟢 Epoch 21, Batch 160, Loss: 0.3890
# 🟢 Epoch 21, Batch 170, Loss: 0.1663
# 🟢 Epoch 21, Batch 180, Loss: 0.3302
# 🟢 Epoch 21, Batch 190, Loss: 0.3208
# 🟢 Epoch 21, Batch 200, Loss: 0.1462
# 🟢 Epoch 21, Batch 210, Loss: 0.1155
# 🟢 Epoch 21, Batch 220, Loss: 0.2841
# 🟢 Epoch 21, Batch 230, Loss: 0.1359
# 🟢 Epoch 21, Batch 240, Loss: 0.3123
# 🟢 Epoch 21, Batch 250, Loss: 0.2098
# 🟢 Epoch 21, Batch 260, Loss: 0.3188
# 🟢 Epoch 21, Batch 270, Loss: 0.2588
# 🟢 Epoch 21, Batch 280, Loss: 0.3012
# 🟢 Epoch 21, Batch 290, Loss: 0.1741
# 🟢 Epoch 21, Batch 300, Loss: 0.1650
# 🟢 Epoch 21, Batch 310, Loss: 0.0918
# 🟢 Epoch 21, Batch 320, Loss: 0.1453
# 🟢 Epoch 21, Batch 330, Loss: 0.0770
# 🟢 Epoch 21, Batch 340, Loss: 0.2418
# 🟢 Epoch 21, Batch 350, Loss: 0.1857
# 🟢 Epoch 21, Batch 360, Loss: 0.1780
# Train Loss: 0.2806
# 🔵 Val Loss: 0.4080, Val Acc: 0.8539, Epoch Time: 137.03 sec
# ⏹️ Early stopping triggered!
# 🎯 Training completed!
# /tmp/ipykernel_15605/2375366292.py:341: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("best_model.pth"))
# Test Accuracy: 0.8091

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, cohen_kappa_score

# Define class names based on your dataset order
class_names = ["Black", "Blue", "Green", "TTR"]

def show_test_sample(dataset, idx, predictions, class_names):
    """
    Displays the test sample at dataset[idx] at input resolution along with its file name,
    predicted and actual labels.
    """
    sample = dataset[idx]
    # Unnormalize image for display
    img_tensor = sample['image']
    # Assume image is normalized with mean=[0.485,0.456,0.406] and std=[0.229,0.224,0.225]
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    img_np = img_tensor.cpu().numpy().transpose(1, 2, 0)
    img_np = np.clip(img_np * std + mean, 0, 1)
    
    actual_label = sample['label'].item()
    predicted_label = predictions[idx]
    # Use .get() with fallback
    file_name = sample.get('file_name', 'unknown')
    
    plt.figure()
    plt.imshow(img_np)
    plt.title(f"File: {file_name}\nPredicted: {class_names[predicted_label]} | Actual: {class_names[actual_label]}")
    plt.axis('off')
    plt.show()
    
    if predicted_label == actual_label:
        print("✅ The prediction is correct.")
    else:
        print("❌ The prediction is incorrect.")

# --- Collect predictions from the test set ---
all_true = []
all_preds = []

model.eval()
with torch.no_grad():
    for batch in test_loader:
        images = batch['image'].to(device)
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['label'].to(device)
        
        outputs = model(images, input_ids, attention_mask)
        preds = torch.argmax(outputs, dim=1)
        
        all_true.append(labels.cpu().numpy())
        all_preds.append(preds.cpu().numpy())

all_true = np.concatenate(all_true)
all_preds = np.concatenate(all_preds)

# --- Compute confusion matrix and metrics ---
cm = confusion_matrix(all_true, all_preds)
overall_accuracy = np.trace(cm) / np.sum(cm)
kappa = cohen_kappa_score(all_true, all_preds)

print(f"Overall Accuracy: {overall_accuracy:.4f}")
print(f"Cohen's Kappa: {kappa:.4f}")

producer_accuracy = cm.diagonal() / cm.sum(axis=1)
user_accuracy = cm.diagonal() / cm.sum(axis=0)
for i in range(len(producer_accuracy)):
    print(f"Class {i}: Producer Accuracy (Recall) = {producer_accuracy[i]:.4f}, User Accuracy (Precision) = {user_accuracy[i]:.4f}")

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# --- Identify correct and incorrect predictions ---
correct_indices = [i for i, (t, p) in enumerate(zip(all_true, all_preds)) if t == p]
incorrect_indices = [i for i, (t, p) in enumerate(zip(all_true, all_preds)) if t != p]

if len(correct_indices) > 0:
    idx_correct = np.random.choice(correct_indices)
    print("\n--- Correct Prediction Example ---")
    show_test_sample(test_dataset, idx_correct, all_preds, class_names)
else:
    print("\nNo correct predictions found!")

if len(incorrect_indices) > 0:
    idx_incorrect = np.random.choice(incorrect_indices)
    print("\n--- Incorrect Prediction Example ---")
    show_test_sample(test_dataset, idx_incorrect, all_preds, class_names)
else:
    print("\nNo incorrect predictions found!")
# Out:
# Overall Accuracy: 0.8091
# Cohen's Kappa: 0.7431
# Class 0: Producer Accuracy (Recall) = 0.6777, User Accuracy (Precision) = 0.6787
# Class 1: Producer Accuracy (Recall) = 0.8186, User Accuracy (Precision) = 0.8111
# Class 2: Producer Accuracy (Recall) = 0.9174, User Accuracy (Precision) = 0.8778
# Class 3: Producer Accuracy (Recall) = 0.8028, User Accuracy (Precision) = 0.8476
# --- Correct Prediction Example ---
# ✅ The prediction is correct.
#
# --- Incorrect Prediction Example ---
# ❌ The prediction is incorrect.
